# %%
import spacy

# %%
nlp = spacy.blank("en")
doc = nlp('''"Let's go to N.Y!"''')

for token in doc:
    print(token)
# Out:
# "
# Let
# 's
# go
# to
# N.Y
# !
# "

# %%
nlp.pipe_names #to check if we have any pipeline rn or not
# Out:
# []

# %%
#To do certain tokenizations we need language module pipelines

nlp = spacy.load("en_core_web_sm")

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipeline#now we got some pipelines
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x13a3776a0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x13a376fe0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x13a39a490>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x137d51840>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x138d30a00>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x13a39a650>)]

# %%
doc = nlp('''The crow started collecting pebbles one by one and dropped them into the pitcher. As more and more pebbles went into the pitcher, the water rose up. Soon enough, the water came to a level through which the crow could drink water. He drank the water happily and thanked mother nature''')

for token in doc:
    print(token, " | ", token.pos_," | ",token.lemma_) 
    ''' 
        lemma_ --> lemetizer --> It will give the base word of the token --> lemmatizer
    '''
# Out:
# The  |  DET  |  the
# crow  |  NOUN  |  crow
# started  |  VERB  |  start
# collecting  |  VERB  |  collect
# pebbles  |  NOUN  |  pebble
# one  |  NUM  |  one
# by  |  ADP  |  by
# one  |  NUM  |  one
# and  |  CCONJ  |  and
# dropped  |  VERB  |  drop
# them  |  PRON  |  they
# into  |  ADP  |  into
# the  |  DET  |  the
# pitcher  |  NOUN  |  pitcher
# .  |  PUNCT  |  .
# As  |  SCONJ  |  as
# more  |  ADJ  |  more
# and  |  CCONJ  |  and
# more  |  ADJ  |  more
# pebbles  |  NOUN  |  pebble
# went  |  VERB  |  go
# into  |  ADP  |  into
# the  |  DET  |  the
# pitcher  |  NOUN  |  pitcher
# ,  |  PUNCT  |  ,
# the  |  DET  |  the
# water  |  NOUN  |  water
# rose  |  VERB  |  rise
# up  |  ADP  |  up
# .  |  PUNCT  |  .
# Soon  |  ADV  |  soon
# enough  |  ADV  |  enough
# ,  |  PUNCT  |  ,
# the  |  DET  |  the
# water  |  NOUN  |  water
# came  |  VERB  |  come
# to  |  ADP  |  to
# a  |  DET  |  a
# level  |  NOUN  |  level
# through  |  ADP  |  through
# which  |  PRON  |  which
# the  |  DET  |  the
# crow  |  NOUN  |  crow
# could  |  AUX  |  could
# drink  |  VERB  |  drink
# water  |  NOUN  |  water
# .  |  PUNCT  |  .
# He  |  PRON  |  he
# drank  |  VERB  |  drink
# the  |  DET  |  the
# water  |  NOUN  |  water
# happily  |  ADV  |  happily
# and  |  CCONJ  |  and
# thanked  |  VERB  |  thank
# mother  |  NOUN  |  mother
# nature  |  NOUN  |  nature

# %%
doc = nlp(''' His dad founded Stark Industries, and as a result his parents were wealthy. It's important to note, though, that Tony doesn't rest on his laurels. Instead, he works hard to make Stark Industries successful. While you may not have wealthy parents, almost everyone has some assets on which they can start building.''')
for ent in doc.ents:
    print(ent.text, " | ", ent.label_," |", spacy.explain(ent.label_)) #ent is a ner pipeline --> ent i.e. entities 
    '''
    ent.label_ --> gives the type of entity the text contains
    '''
# Out:
# Stark Industries  |  ORG  | Companies, agencies, institutions, etc.
# Tony  |  PERSON  | People, including fictional
# Stark Industries  |  ORG  | Companies, agencies, institutions, etc.

# %%
# FOR PRE-DEFINED LANGUAGE PIPELINES WE CAN VISIT SPACY-LANGUAGE AND MODULES ON THE INTERNET

# %%
from spacy import displacy #For better representation of the entity

displacy.render(doc, style ="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> His dad founded
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stark Industries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and as a result his parents were wealthy. It's important to note, though, that
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  doesn't rest on his laurels. Instead, he works hard to make
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Stark Industries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  successful. While you may not have wealthy parents, almost everyone has some assets on which they can start building.</div></span>

# %%
#an example with WW2 text from a book 

doc = nlp('''World War I left unresolved the question of who would dominate
Europe. The tremendous dislocations caused by the war laid the
groundwork for the collapse of democratic institutions there and set
the stage for a second German attempt at conquest. A worldwide depression that began in 1929 destroyed the fragile democratic regime
in Germany. In 1933 Adolf Hitler led to power the National Socialist German Workers’ (Nazi) Party, a mass movement that was virulently nationalistic, antidemocratic, and anti-Semitic. He ended parliamentary government, assumed dictatorial powers, and proclaimed
the Third Reich. The Nazi government increased the strength of the
German armed forces and sought to overturn the Versailles Treaty,
to recover German territory lost at the peace settlement, and to return to the so-called Fatherland German-speaking minorities within
the borders of surrounding countries.
The ultimate goal of Hitler’s policy was to secure “living space” for
the German “master race” in eastern Europe. A gambler by instinct,
Hitler relied on diplomatic bluff and military innovation to overcome
Germany’s weaknesses. He played skillfully on the divisions among
the European powers to gain many of his aims without war. With the
Italian Fascist dictator Benito Mussolini he announced a RomeBerlin alliance (the Axis) in 1935. Meanwhile, in the Far East, the
Japanese—the only Asian industrial power—coveted the natural resources of China and Southeast Asia, but found their expansion
blocked by European colonial powers or by the United States. Having seized Manchuria in 1931, they began a war against China in 1937.
The League of Nations failed to counter effectively Japanese aggression in Manchuria and an Italian invasion of Ethiopia. Soon Germany, Italy, and Japan became allies, facing Western democratic governments that wanted to avoid another war and the Soviet Union
whose Communist government was widely distrusted.
The people of the United States, having rejected the Versailles
Treaty and the Covenant of the League of Nations after World War
I, remained largely indifferent to most international concerns. They
firmly discounted the likelihood of American involvement in an-
4
other major war, except perhaps with Japan. Isolationist strength in
Congress led to the passage of the Neutrality Act of 1937, making it
unlawful for the United States to trade with belligerents. American
policy aimed at continental defense and designated the Navy as the
first line of such defense. The Army’s role was to serve as the nucleus of a mass mobilization that would defeat any invaders who
managed to fight their way past the Navy and the nation’s powerful
coastal defense installations. The National Defense Act of 1920 allowed an Army of 280,000, the largest in peacetime history, but until
1939 Congress never appropriated funds to pay for much more than
half of that strength. ''')

displacy.render(doc, style = "ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War I
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  left unresolved the question of who would dominate<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . The tremendous dislocations caused by the war laid the<br>groundwork for the collapse of democratic institutions there and set<br>the stage for a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  attempt at conquest. A worldwide depression that began in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1929
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  destroyed the fragile democratic regime<br>in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1933
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adolf Hitler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  led to power
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the National Socialist German Workers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’ (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nazi) Party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a mass movement that was virulently nationalistic, antidemocratic, and
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     anti-Semitic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# . He ended parliamentary government, assumed dictatorial powers, and proclaimed<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Third Reich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . The
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nazi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  government increased the strength of the<br>
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  armed forces and sought to overturn
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Versailles Treaty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# ,<br>to recover
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  territory lost at the peace settlement, and to return to the so-called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fatherland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LANGUAGE</span>
# </mark>
# -speaking minorities within<br>the borders of surrounding countries.<br>The ultimate goal of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hitler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s policy was to secure “living space” for<br>the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     German
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  “master race” in eastern
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# . A gambler by instinct,<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hitler
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  relied on diplomatic bluff and military innovation to overcome<br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left:

# %%
for token in doc:
    print(token.i, " --> ", token)
# Out:
# 0  -->  World
# 1  -->  War
# 2  -->  I
# 3  -->  left
# 4  -->  unresolved
# 5  -->  the
# 6  -->  question
# 7  -->  of
# 8  -->  who
# 9  -->  would
# 10  -->  dominate
# 11  -->
#
# 12  -->  Europe
# 13  -->  .
# 14  -->  The
# 15  -->  tremendous
# 16  -->  dislocations
# 17  -->  caused
# 18  -->  by
# 19  -->  the
# 20  -->  war
# 21  -->  laid
# 22  -->  the
# 23  -->
#
# 24  -->  groundwork
# 25  -->  for
# 26  -->  the
# 27  -->  collapse
# 28  -->  of
# 29  -->  democratic
# 30  -->  institutions
# 31  -->  there
# 32  -->  and
# 33  -->  set
# 34  -->
#
# 35  -->  the
# 36  -->  stage
# 37  -->  for
# 38  -->  a
# 39  -->  second
# 40  -->  German
# 41  -->  attempt
# 42  -->  at
# 43  -->  conquest
# 44  -->  .
# 45  -->  A
# 46  -->  worldwide
# 47  -->  depression
# 48  -->  that
# 49  -->  began
# 50  -->  in
# 51  -->  1929
# 52  -->  destroyed
# 53  -->  the
# 54  -->  fragile
# 55  -->  democratic
# 56  -->  regime
# 57  -->
#
# 58  -->  in
# 59  -->  Germany
# 60  -->  .
# 61  -->  In
# 62  -->  1933
# 63  -->  Adolf
# 64  -->  Hitler
# 65  -->  led
# 66  -->  to
# 67  -->  power
# 68  -->  the
# 69  -->  National
# 70  -->  Socialist
# 71  -->  German
# 72  -->  Workers
# 73  -->  ’
# 74  -->  (
# 75  -->  Nazi
# 76  -->  )
# 77  -->  Party
# 78  -->  ,
# 79  -->  a
# 80  -->  mass
# 81  -->  movement
# 82  -->  that
# 83  -->  was
# 84  -->  virulently
# 85  -->  nationalistic
# 86  -->  ,
# 87  -->  antidemocratic
# 88  -->  ,
# 89  -->  and
# 90  -->  anti
# 91  -->  -
# 92  -->  Semitic
# 93  -->  .
# 94  -->  He
# 95  -->  ended
# 96  -->  parliamentary
# 97  -->  government
# 98  -->  ,
# 99  -->  assumed
# 100  -->  dictatorial
# 101  -->  powers
# 102  -->  ,
# 103  -->  and
# 104  -->  proclaimed
# 105  -->
#
# 106  -->  the
# 107  -->  Third
# 108  -->  Reich
# 109  -->  .
# 110  -->  The
# 111  -->  Nazi
# 112  -->  government
# 113  -->  increased
# 114  -->  the
# 115  -->  strength
# 116  -->  of
# 117  -->  the
# 118  -->
#
# 119  -->  German
# 120  -->  armed
# 121  -->  forces
# 122  -->  and
# 123  -->  sought
# 124  -->  to
# 125  -->  overturn
# 126  -->  the
# 127  -->  Versailles
# 128  -->  Treaty
# 129  -->  ,
# 130  -->
#
# 131  -->  to
# 132  -->  recover
# 133  -->  German
# 134  -->  territory
# 135  -->  lost
# 136  -->  at
# 137  -->  the
# 138  -->  peace
# 139  -->  settlement
# 140  -->  ,
# 141  -->  and
# 142  -->  to
# 143  -->  return
# 144  -->  to
# 145  -->  the
# 146  -->  so
# 147  -->  -
# 148  -->  called
# 149  -->  Fatherland
# 150  -->  German
# 151  -->  -
# 152  -->  speaking
# 153  -->  minorities
# 154  -->  within
# 155  -->
#
# 156  -->  the
# 157  -->  borders
# 158  -->  of
# 159  -->  surrounding
# 160  -->  countries
# 161  -->  .
# 162  -->
#
# 163  -->  The
# 164  -->  ultimate
# 165  -->  goal
# 166  -->  of
# 167  -->  Hitler
# 168  -->  ’s
# 169  -->  policy
# 170  -->  was
# 171  -->  to
# 172  -->  secure
# 173  -->  “
# 174  -->  living
# 175  -->  space
# 176  -->  ”
# 177  -->  for
# 178  -->
#
# 179  -->  the
# 180  -->  German
# 181  -->  “
# 182  -->  master
# 183  -->  race
# 184  -->  ”
# 185  -->  in
# 186  -->  eastern
# 187  -->  Europe
# 188  -->  .
# 189  -->  A
# 190  -->  gambler
# 191  -->  by
# 192  -->  instinct
# 193  -->  ,
# 194  -->
#
# 195  -->  Hitler
# 196  -->  relied
# 197  -->  on
# 198  -->  diplomatic
# 199  -->  bluff
# 200  -->  and
# 201  -->  military
# 202  -->  innovation
# 203  -->  to
# 204  -->  overcome
# 205  -->
#
# 206  -->  Germany
# 207  -->  ’s
# 208  -->  weaknesses
# 209  -->  .
# 210  -->  He
# 211  -->  played
# 212  -->  skillfully
# 213  -->  on
# 214  -->  the
# 215  -->  divisions
# 216  -->  among
# 217  -->
#
# 218  -->  the
# 219  -->  European
# 220  -->  powers
# 221  -->  to
# 222  -->  gain
# 223  -->  many
# 224  -->  of
# 225  -->  his
# 226  -->  aims
# 227  -->  without
# 228  -->  war
# 229  -->  .
# 230  -->  With
# 231  -->  the
# 232  -->
#
# 233  -->  Italian
# 234  -->  Fascist
# 235  -->  dictator
# 236  -->  Benito
# 237  -->  Mussolini
# 238  -->  he
# 239  -->  announced
# 240  -->  a
# 241  -->  RomeBerlin
# 242  -->  alliance
# 243  -->  (
# 244  -->  the
# 245  -->  Axis
# 246  -->  )
# 247  -->  in
# 248  -->  1935
# 249  -->  .
# 250  -->  Meanwhile
# 251  -->  ,
# 252  -->  in
# 253  -->  the
# 254  -->  Far
# 255  -->  East
# 256  -->  ,
# 257  -->  the
# 258  -->
#
# 259  -->  Japanese
# 260  -->  —
# 261  -->  the
# 262  -->  only
# 263  -->  Asian
# 264  -->  industrial
# 265  -->  power
# 266  -->  —
# 267  -->  coveted
# 268  -->  the
# 269  -->  natural
# 270  -->  resources
# 271  -->  of
# 272  -->  China
# 273  -->  and
# 274  -->  Southeast
# 275  -->  Asia
# 276  -->  ,
# 277  -->  but
# 278  -->  found
# 279  -->  their
# 280  -->  expansion
# 281  -->
#
# 282  -->  blocked
# 283  -->  by
# 284  -->  European
# 285  -->  colonial
# 286  -->  powers
# 287  -->  or
# 288  -->  by
# 289  -->  the
# 290  -->  United
# 291  -->  States
# 292  -->  .
# 293  -->  Having
# 294  -->  seized
# 295  -->  Manchuria
# 296  -->  in
# 297  -->  1931
# 298  -->  ,
# 299  -->  they
# 300  -->  began
# 301  -->  a
# 302  -->  war
# 303  -->  against
# 304  -->  China
# 305  -->  in
# 306  -->  1937
# 307  -->  .
# 308  -->
#
# 309  -->  The
# 310  -->  League
# 311  -->  of
# 312  -->  Nations
# 313  -->  failed
# 314  -->  to
# 315  -->  counter
# 316  -->  effectively
# 317  -->  Japanese
# 318  -->  aggression
# 319  -->  in
# 320  -->  Manchuria
# 321  -->  and
# 322  -->  an
# 323  -->  Italian
# 324  -->  invasion
# 325  -->  of
# 326  -->  Ethiopia
# 327  -->  .
# 328  -->  Soon
# 329  -->  Germany
# 330  -->  ,
# 331  -->  Italy
# 332  -->  ,
# 333  -->  and
# 334  -->  Japan
# 335  -->  became
# 336  -->  allies
# 337  -->  ,
# 338  -->  facing
# 339  -->  Western
# 340  -->  democratic
# 341  -->  governments
# 342  -->  that
# 343  -->  wanted
# 344  -->  to
# 345  -->  avoid
# 346  -->  another
# 347  -->  war
# 348  -->  and
# 349  -->  the
# 350  -->  Soviet
# 351  -->  Union
# 352  -->
#
# 353  -->  whose
# 354  -->  Communist
# 355  -->  government
# 356  -->  was
# 357  -->  widely
# 358  -->  distrusted
# 359  -->  .
# 360  -->
#
# 361  -->  The
# 362  -->  people
# 363  -->  of
# 364  -->  the
# 365  -->  United
# 366  -->  States
# 367  -->  ,
# 368  -->  having
# 369  -->  rejected
# 370  -->  the
# 371  -->  Versailles
# 372  -->
#
# 373  -->  Treaty
# 374  -->  and
# 375  -->  the
# 376  -->  Covenant
# 377  -->  of
# 378  -->  the
# 379  -->  League
# 380  -->  of
# 381  -->  Nations
# 382  -->  after
# 383  -->  World
# 384  -->  War
# 385  -->
#
# 386  -->  I
# 387  -->  ,
# 388  -->  remained
# 389  -->  largely
# 390  -->  indifferent
# 391  -->  to
# 392  -->  most
# 393  -->  international
# 394  -->  concerns
# 395  -->  .
# 396  -->  They
# 397  -->
#
# 398  -->  firmly
# 399  -->  discounted
# 400  -->  the
# 401  -->  likelihood
# 402  -->  of
# 403  -->  American
# 404  -->  involvement
# 405  -->  in
# 406  -->  an-
# 407  -->
#
# 408  -->  4
# 409  -->
#
# 410  -->  other
# 411  -->  major
# 412  -->  war
# 413  -->  ,
# 414  -->  except
# 415  -->  perhaps
# 416  -->  with
# 417  -->  Japan
# 418  -->  .
# 419  -->  Isolationist
# 420  -->  strength
# 421  -->  in
# 422  -->
#
# 423  -->  Congress
# 424  -->  led
# 425  -->  to
# 426  -->  the
# 427  -->  passage
# 428  -->  of
# 429  -->  the
# 430  -->  Neutrality
# 431  -->  Act
# 432  -->  of
# 433  -->  1937
# 434  -->  ,
# 435  -->  making
# 436  -->  it
# 437  -->
#
# 438  -->  unlawful
# 439  -->  for
# 440  -->  the
# 441  -->  United
# 442  -->  States
# 443  -->  to
# 444  -->  trade
# 445  -->  with
# 446  -->  belligerents
# 447  -->  .
# 448  -->  American
# 449  -->
#
# 450  -->  policy
# 451  -->  aimed
# 452  -->  at
# 453  -->  continental
# 454  -->  defense
# 455  -->  and
# 456  -->  designated
# 457  -->  the
# 458  -->  Navy
# 459  -->  as
# 460  -->  the
# 461  -->
#
# 462  -->  first
# 463  -->  line
# 464  -->  of
# 465  -->  such
# 466  -->  defense
# 467  -->  .
# 468  -->  The
# 469  -->  Army
# 470  -->  ’s
# 471  -->  role
# 472  -->  was
# 473  -->  to
# 474  -->  serve
# 475  -->  as
# 476  -->  the
# 477  -->  nucleus
# 478  -->  of
# 479  -->  a
# 480  -->  mass
# 481  -->  mobilization
# 482  -->  that
# 483  -->  would
# 484  -->  defeat
# 485  -->  any
# 486  -->  invaders
# 487  -->  who
# 488  -->
#
# 489  -->  managed
# 490  -->  to
# 491  -->  fight
# 492  -->  their
# 493  -->  way
# 494  -->  past
# 495  -->  the
# 496  -->  Navy
# 497  -->  and
# 498  -->  the
# 499  -->  nation
# 500  -->  ’s
# 501  -->  powerful
# 502  -->
#
# 503  -->  coastal
# 504  -->  defense
# 505  -->  installations
# 506  -->  .
# 507  -->  The
# 508  -->  National
# 509  -->  Defense
# 510  -->  Act
# 511  -->  of
# 512  -->  1920
# 513  -->  allowed
# 514  -->  an
# 515  -->  Army
# 516  -->  of
# 517  -->  280,000
# 518  -->  ,
# 519  -->  the
# 520  -->  largest
# 521  -->  in
# 522  -->  peacetime
# 523  -->  history
# 524  -->  ,
# 525  -->  but
# 526  -->  until
# 527  -->
#
# 528  -->  1939
# 529  -->  Congress
# 530  -->  never
# 531  -->  appropriated
# 532  -->  funds
# 533  -->  to
# 534  -->  pay
# 535  -->  for
# 536  -->  much
# 537  -->  more
# 538  -->  than
# 539  -->
#
# 540  -->  half
# 541  -->  of
# 542  -->  that
# 543  -->  strength
# 544  -->  .

# %%
# To add a particular pipeline, not the whole thing
source_nlp = spacy.load("en_core_web_sm")

nlp = spacy.blank("en") # no pipeline here

nlp.add_pipe("ner", source = source_nlp) # ner pipeline is added
nlp.pipe_names
# Out:
# ['ner']
